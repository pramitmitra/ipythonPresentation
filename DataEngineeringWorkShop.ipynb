# %% [markdown]
# # What is Jupyter Notebook?
#
# * The Jupyter Notebook is an interactive computing environment that enables users to author notebook documents that include: - Live code - Interactive widgets - Plots - Narrative text - Equations - Images - Video
# * Enables code and text combination for user convenient. ### Components
# * The notebook web application: An interactive web application for writing and running code interactively and authoring notebook documents.
# * Kernels: Separate processes started by the notebook web application that runs users’ code in a given language and returns output back to the notebook web application.
# * Notebook documents: Self-contained documents that contain a representation of all content visible in the notebook web application, including inputs and outputs of the computations, narrative text, equations, images, and rich media representations of objects. ### Notebook Notebook documents contain the only the input and output of the interactive session. When you run the notebook web application on your computer, notebook documents are just files on your local filesystem with a .ipynb extension. This format will serve us when submitting the HWs. These files are JSON files, which are rendered in the web browser

# %% [markdown]
# # 1. Open notebook dashboard
# cmd -> type "jupyter notebook"
# Open an existing .ipynb and create a new one
# File browser
#
# # 2. Overview of the Notebook UI
# Consists of:
#
# Menu (save, Insert cells, Kernel)
# Toolbar
# Notebook area and cells (It is recommended to try the interactive tour in the "Help:User Interface Tour")
# Cell types:
# Code cell: Input and output of code that is run in the kernel
# Markdown cells: Narrative text
# Raw cells
# Learn the keyboard shortbuts which you will find very useful, such as: Shift+Enter, a, b ...
#
# # 3. Code cells
# * Cell menu
# * Kernel menu

# %%
print ('Hello world')
# Out:
# Hello world

# %% [markdown]
# # Assigning variables

# %%
x = 5 #assignment
y = x + 2
x==4 #condition
# Out:
# False

# %% [markdown]
# # importing

# %%
import numpy as np

# %%
print (np.random.random())
# Out:
# 0.5517615626315222

# %%
#defining a function
def fun(v):
    '''2nd power function'''
    return np.power(v,2)

# %%
for i in range(10): #for loop
    print (i,fun(i))
# Out:
# 0 0
# 1 1
# 2 4
# 3 9
# 4 16
# 5 25
# 6 36
# 7 49
# 8 64
# 9 81

# %% [markdown]
# # Matplotlib

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x = np.linspace(0, 100)
y = np.sqrt(x)

# %%
print (x)
print (y)
# Out:
# [  0.           2.04081633   4.08163265   6.12244898   8.16326531
#   10.20408163  12.24489796  14.28571429  16.32653061  18.36734694
#   20.40816327  22.44897959  24.48979592  26.53061224  28.57142857
#   30.6122449   32.65306122  34.69387755  36.73469388  38.7755102
#   40.81632653  42.85714286  44.89795918  46.93877551  48.97959184
#   51.02040816  53.06122449  55.10204082  57.14285714  59.18367347
#   61.2244898   63.26530612  65.30612245  67.34693878  69.3877551
#   71.42857143  73.46938776  75.51020408  77.55102041  79.59183673
#   81.63265306  83.67346939  85.71428571  87.75510204  89.79591837
#   91.83673469  93.87755102  95.91836735  97.95918367 100.        ]
# [ 0.          1.42857143  2.02030509  2.4743583   2.85714286  3.19438282
#   3.49927106  3.77964473  4.04061018  4.28571429  4.51753951  4.73803541
#   4.94871659  5.15078754  5.34522484  5.53283335  5.71428571  5.89015089
#   6.06091527  6.22699849  6.38876565  6.54653671  6.70059394  6.85118789
# ...

# %%
plt.plot(x, y)
plt.show()

# %% [markdown]
# # petl
# ## pETL is a general purpose Python package for extracting, transforming and loading tables of data.
# ## Extract & Load : http://petl.readthedocs.io/en/latest/io.html
# ## transform: http://petl.readthedocs.io/en/latest/transform.html
#
# ### install petl by running pip install petl in Command-Line

# %%
import petl as etl

# %%
table1 = etl.fromcsv('/Users/pmitra/Documents/myProjects/Presentations/Data/example.csv')

# %%
table1
# Out:
# +-----+-----+-----+
# | 1   | 2   | 3   |
# +=====+=====+=====+
# | '4' | '5' | '6' |
# +-----+-----+-----+
# | '7' | '8' | '9' |
# +-----+-----+-----+

# %%
filename= '/Users/pmitra/Documents/myProjects/Presentations/Data/population.csv'

# %%
t1 = etl.fromcsv(filename)
t1.display(5)
# Out:
# <table class='petl'>
# <thead>
# <tr>
# <th>﻿CountryName</th>
# <th>CountryCode</th>
# <th>IndicatorName</th>
# <th>IndicatorCode</th>
# <th>PopCode</th>
# <th>1960</th>
# <th>1961</th>
# <th>1962</th>
# <th>1963</th>
# <th>1964</th>
# <th>1965</th>
# <th>1966</th>
# <th>1967</th>
# <th>1968</th>
# <th>1969</th>
# <th>1970</th>
# <th>1971</th>
# <th>1972</th>
# <th>1973</th>
# <th>1974</th>
# <th>1975</th>
# <th>1976</th>
# <th>1977</th>
# <th>1978</th>
# <th>1979</th>
# <th>1980</th>
# <th>1981</th>
# <th>1982</th>
# <th>1983</th>
# <th>1984</th>
# <th>1985</th>
# <th>1986</th>
# <th>1987</th>
# <th>1988</th>
# <th>1989</th>
# <th>1990</th>
# <th>1991</th>
# <th>1992</th>
# <th>1993</th>
# <th>1994</th>
# <th>1995</th>
# <th>1996</th>
# <th>1997</th>
# <th>1998</th>
# <th>1999</th>
# <th>2000</th>
# <th>2001</th>
# <th>2002</th>
# <th>2003</th>
# <th>2004</th>
# <th>2005</th>
# <th>2006</th>
# <th>2007</th>
# <th>2008</th>
# <th>2009</th>
# <th>2010</th>
# <th>2011</th>
# ...

# %% [markdown]
# # Count(*)

# %%
t1.nrows()
# Out:
# 264

# %% [markdown]
# # Retrieving fields

# %%
fields = t1.fieldnames()
print (fields)
# Out:
# ('\ufeffCountryName', 'CountryCode', 'IndicatorName', 'IndicatorCode', '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968', '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977', '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986', '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018')

# %% [markdown]
# # Accessing specific value

# %%
print ((t1[1][2]))
# Out:
# Population

# %%
# Data Type

# %%
for f in fields:
    print (f,'\t', t1.typecounter(f))
# Out:
# ﻿CountryName 	 Counter({'str': 264})
# CountryCode 	 Counter({'str': 264})
# IndicatorName 	 Counter({'str': 264})
# IndicatorCode 	 Counter({'str': 264})
# 1960 	 Counter({'str': 264})
# 1961 	 Counter({'str': 264})
# 1962 	 Counter({'str': 264})
# 1963 	 Counter({'str': 264})
# 1964 	 Counter({'str': 264})
# 1965 	 Counter({'str': 264})
# 1966 	 Counter({'str': 264})
# 1967 	 Counter({'str': 264})
# 1968 	 Counter({'str': 264})
# 1969 	 Counter({'str': 264})
# 1970 	 Counter({'str': 264})
# 1971 	 Counter({'str': 264})
# 1972 	 Counter({'str': 264})
# 1973 	 Counter({'str': 264})
# 1974 	 Counter({'str': 264})
# 1975 	 Counter({'str': 264})
# 1976 	 Counter({'str': 264})
# 1977 	 Counter({'str': 264})
# 1978 	 Counter({'str': 264})
# 1979 	 Counter({'str': 264})
# 1980 	 Counter({'str': 264})
# 1981 	 Counter({'str': 264})
# 1982 	 Counter({'str': 264})
# 1983 	 Counter({'str': 264})
# 1984 	 Counter({'str': 264})
# 1985 	 Counter({'str': 264})
# 1986 	 Counter({'str': 264})
# ...

# %%
t1.display(5)
# Out:
# <table class='petl'>
# <thead>
# <tr>
# <th>﻿CountryName</th>
# <th>CountryCode</th>
# <th>IndicatorName</th>
# <th>IndicatorCode</th>
# <th>PopCode</th>
# <th>1960</th>
# <th>1961</th>
# <th>1962</th>
# <th>1963</th>
# <th>1964</th>
# <th>1965</th>
# <th>1966</th>
# <th>1967</th>
# <th>1968</th>
# <th>1969</th>
# <th>1970</th>
# <th>1971</th>
# <th>1972</th>
# <th>1973</th>
# <th>1974</th>
# <th>1975</th>
# <th>1976</th>
# <th>1977</th>
# <th>1978</th>
# <th>1979</th>
# <th>1980</th>
# <th>1981</th>
# <th>1982</th>
# <th>1983</th>
# <th>1984</th>
# <th>1985</th>
# <th>1986</th>
# <th>1987</th>
# <th>1988</th>
# <th>1989</th>
# <th>1990</th>
# <th>1991</th>
# <th>1992</th>
# <th>1993</th>
# <th>1994</th>
# <th>1995</th>
# <th>1996</th>
# <th>1997</th>
# <th>1998</th>
# <th>1999</th>
# <th>2000</th>
# <th>2001</th>
# <th>2002</th>
# <th>2003</th>
# <th>2004</th>
# <th>2005</th>
# <th>2006</th>
# <th>2007</th>
# <th>2008</th>
# <th>2009</th>
# <th>2010</th>
# <th>2011</th>
# ...

# %% [markdown]
# # Transform
# ## Lets define a function to do some transformation work

# %%
def cleanup(text):
    return (text[:-9])

print (cleanup('SP.POP.TOTL'))
# Out:
# SP

# %% [markdown]
# # Lets apply this function to each row

# %%
t2 = t1.convert('PopCode',cleanup)

# %%
print (t2.typecounter('PopCode'))
t2.display(10)
# Out:
# Counter({'str': 264})
# <table class='petl'>
# <thead>
# <tr>
# <th>﻿CountryName</th>
# <th>CountryCode</th>
# <th>IndicatorName</th>
# <th>IndicatorCode</th>
# <th>PopCode</th>
# <th>1960</th>
# <th>1961</th>
# <th>1962</th>
# <th>1963</th>
# <th>1964</th>
# <th>1965</th>
# <th>1966</th>
# <th>1967</th>
# <th>1968</th>
# <th>1969</th>
# <th>1970</th>
# <th>1971</th>
# <th>1972</th>
# <th>1973</th>
# <th>1974</th>
# <th>1975</th>
# <th>1976</th>
# <th>1977</th>
# <th>1978</th>
# <th>1979</th>
# <th>1980</th>
# <th>1981</th>
# <th>1982</th>
# <th>1983</th>
# <th>1984</th>
# <th>1985</th>
# <th>1986</th>
# <th>1987</th>
# <th>1988</th>
# <th>1989</th>
# <th>1990</th>
# <th>1991</th>
# <th>1992</th>
# <th>1993</th>
# <th>1994</th>
# <th>1995</th>
# <th>1996</th>
# <th>1997</th>
# <th>1998</th>
# <th>1999</th>
# <th>2000</th>
# <th>2001</th>
# <th>2002</th>
# <th>2003</th>
# <th>2004</th>
# <th>2005</th>
# <th>2006</th>
# <th>2007</th>
# <th>2008</th>
# <th>2009</th>
# <th>2010</th>
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

x, y = np.loadtxt('/Users/pmitra/Documents/myProjects/Presentations/Data/plot_exmple.txt', delimiter=',', unpack=True)
plt.plot(x,y, label='Loaded from file!')

plt.xlabel('x')
plt.ylabel('y')
plt.title('Interesting Graph\nCheck it out')
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import math
import datetime as dt

test = """16:58:58 | 2.090 | 26.88  | 1.2945E-9  |   45.8\n
16:59:00 | 2.031 | 27.00  | 1.3526E-9  |  132.1\n
16:59:02 | 2.039 | 26.90  | 1.3843E-9  |  178.5\n
16:59:04 | 2.031 | 26.98  | 1.4628E-9  |  228.9\n
16:59:06 | 2.031 | 27.04  | 1.5263E-9  |  259.8\n
16:59:08 | 2.027 | 26.84  | 1.6010E-9  |  271.8\n"""

lines = [line for line in test.splitlines() if line != ""]

# Here is the real code
subset = []

for line in lines:
    parts = line.split('|')
    ts = dt.datetime.strptime(parts[0].strip(), "%H:%M:%S")
    num = math.log(float(parts[3].strip()))
    subset.append((ts, num))

# now there is a list of tuples with your datapoints, looking like
# [(datetime.datetime(1900, 1, 1, 16, 58, 58), 1.2945E-9), (datetime.datetime(1900, 1, 1, 16, 59), ...]
# I made this list intentionally so that you can see how one can gather everything in a tidy way from the
# raw string data.

# Now lets separate things for plotting
times = [elem[0] for elem in subset]
values = [elem[1] for elem in subset]

# now to plot, I'm going to use the matplotlib plot_date function.
plt.figure()
plt.plot_date(times, values)
# do some formatting on the date axis
plt.gcf().autofmt_xdate()
plt.show()

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
time = [0, 1, 2, 3]
position = [0, 100, 200, 300]

plt.plot(time, position)
plt.xlabel('Time (hr)')
plt.ylabel('Position (km)')
# Out:
# Text(0,0.5,'Position (km)')

# %%
import pandas

data = pandas.read_csv('data/population_limit.csv', index_col='CountryName')

# Extract year from last 4 characters of each column name
years = data.columns.str.strip('year_')
# Convert year values to integers, saving results back to dataframe
data.columns = years.astype(int)

id = 'USA'
data.loc[id].plot()

# %%
import pandas

data = pandas.read_csv('data/population_UIAW.csv', index_col='CountryName')

# Extract year from last 4 characters of each column name
years = data.columns.str.strip('year_')
# Convert year values to integers, saving results back to dataframe
data.columns = years.astype(int)

data.loc[id].plot()

# %%
data.T.plot()
plt.ylabel('Population capita')
# Out:
# Text(0,0.5,'Population capita')

# %%
plt.style.use('ggplot')
data.T.plot(kind='bar')
plt.ylabel('Population per country')
# Out:
# Text(0,0.5,'Population per country')

# %%
years = data.columns
gdp_australia = data.loc['Australia']

plt.plot(years, gdp_australia, 'g--')

# %%
# Select two countries' worth of data.
pop_australia = data.loc['Australia']
pop_usa = data.loc['USA']

# Plot with differently-colored markers.
plt.plot(years, pop_australia, 'b-', label='Australia')
plt.plot(years, pop_usa, 'g-', label='USA')

# Create legend.
plt.legend(loc='upper left')
plt.xlabel('Year')
plt.ylabel('Population')
# Out:
# Text(0,0.5,'Population')

# %%
plt.scatter(pop_australia, pop_usa)

# %%
data.T.plot.scatter(x = 'Australia', y = 'USA')
